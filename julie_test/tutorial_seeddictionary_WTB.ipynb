# %%
import ddr

# %% [markdown]
# # set paths

# %%
# set path to a Word2Vec model; in this case, GoogleNews 
model_path = "../GoogleNews-vectors-negative300.bin"

# set path to dictionary dimensions of interest, where 1 text file=relevant words
dic_path = "../dictionary_dir/"

#Define path where data files ready for input are stored
#documents_path = / "./test_corpus/input_testing.txt"

# Define path to write dictionary representations to file & load them when calcculating doc loadings
#dictionary_vector_path="./agg_dic_vecs_testing.tsv"

# Define path to both 1) write document representations and 2) read them when calculating document loadings.
#document_vector_path="./test_corpus/output_testing2.tsv"

# Write document loadings to file
#out_path="document_dictionary_loadings_testing.tsv",

# %% [markdown]
# # Load word2vec model
# In order to generate a distributed representation of a dictionary, a model (set of pre-trained vectors) must be loaded and several features must be extracted from the model.
#
# Specifically, the dimensionality of the model and the vocabulary of the model must be stored as objects.

# %%
loaded_model, loaded_num_features, loaded_model_word_set=ddr.load_model(model_path)
# Out:
# 2024-03-31 15:14:56,868 : INFO : loading projection weights from ../GoogleNews-vectors-negative300.bin
# 2024-03-31 15:15:11,679 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (3000000, 300) matrix of type float32 from ../GoogleNews-vectors-negative300.bin', 'binary': True, 'encoding': 'utf8', 'datetime': '2024-03-31T15:15:11.679733', 'gensim': '4.2.0', 'python': '3.7.16 (default, Jan 17 2023, 22:20:44) \n[GCC 11.2.0]', 'platform': 'Linux-6.5.0-26-generic-x86_64-with-debian-trixie-sid', 'event': 'load_word2vec_format'}
# Finished loading model

# %% [markdown]
# # Creating dictionary and document representations
# The next step is to generate distributed dictionary representations.
# First, you need to load the terms that represent each dictionary construct.

# %%
# try loading dictionary
loaded_dic_terms = ddr.terms_from_txt(input_path = dic_path)

# %% [markdown]
# # Make aggregate distributed dictionary representations
# Next, you need to aggregate the representations of each word associated with a construct to create a distributed representation of that construct.

# %%
agg_dic_vecs = ddr.dic_vecs(dic_terms = loaded_dic_terms,
                            model = loaded_model,
                            num_features = loaded_num_features,
                            model_word_set = loaded_model_word_set)
# Out:
# doing authority.vice.txt; [b'disrespect', b'disobey', b'disobedience', b'anarchy', b'chaos', b'subversion', b'subvert', b'lawlessness', b'subverting', b'disrespecting', b'sedition', b'treason', b'overthrow', b'insurrection', b'rebellion', b'transgress', b'treachery', b'dissent', b'dishonor', b'dissension', b'disrespects', b'bedlam', b'rebelling', b'misrule', b'transgression', b'insurrectional', b'pandemonium', b'mutiny', b'mutinies', b'misruling', b'disobedient', b'subverted', b'transgresses', b'transgressed', b'disarray', b'misruled', b'rioting', b'lawless', b'transgressing', b'illegality', b'overthrowing', b'dishonorable', b'dishonoring', b'rebelled', b'rebellions', b'riot', b'dishonouring', b'disrespected', b'permissiveness', b'refuser', b'unruly', b'subverts', b'unlawfulness', b'overthrown', b'anarchistic', b'dishonours', b'riots', b'refuse', b'chaotic', b'nonconformity', b'dissenters', b'uprising', b'insurrections', b'rioters', b'disordering', b'insubordinate', b'mutinied', b'insurrectionist', b'unlawful', b'nonconformists', b'heresy', b'uprisings', b'dishonors', b'tumult', b'overthrew', b'overthrows', b'rabble', b'rousers', b'renegade', b'impolite', b'renegades', b'rabble', b'rousing', b'dishonored', b'illegal', b'rioter', b'mutinous', b'disarrayed', b'apostates', b'dissidents', b'anarchists', b'raise', b'hell', b'disorder', b'refusers', b'permissive', b'apostate', b'anarchist', b'treacherous', b'dissident', b'raises', b'hell', b'disordered', b'heretic', b'overpower', b'rabble', b'rouser', b'rebel', b'raising', b'hell', b'heretics', b'unauthorized', b'refusing', b'rebels', b'refuses', b'rioted', b'orders', b'dissenter', b'chaotically', b'nonconformist', b'heresies', b'illegals', b'unlawfully', b'heretical', b'dissents', b'traditions', b'dissenting', b'overpowers', b'trouble', b'maker', b'refused', b'rock', b'the', b'boat', b'overpowering', b'tumultuous', b'overpowered', b'dissented', b'nonconforming']
# looking for disrespect
# found disrespect in model
# count is now 1.0
# looking for disobey
# found disobey in model
# count is now 2.0
# looking for disobedience
# found disobedience in model
# count is now 3.0
# looking for anarchy
# found anarchy in model
# count is now 4.0
# looking for chaos
# found chaos in model
# count is now 5.0
# looking for subversion
# found subversion in model
# count is now 6.0
# looking for subvert
# found subvert in model
# count is now 7.0
# looking for lawlessness
# found lawlessness in model
# count is now 8.0
# looking for subverting
# found subverting in model
# count is now 9.0
# looking for disrespecting
# found disrespecting in model
# count is now 10.0
# looking for sedition
# found sedition in model
# count is now 11.0
# looking for treason
# found treason in model
# count is now 12.0
# looking for overthrow
# found overthrow in model
# count is now 13.0
# looking for insurrection
# found insurrection in model
# count is now 14.0
# looking for rebellion
# found rebellion in model
# count is now 15.0
# looking for transgress
# found transgress in model
# count is now 16.0
# looking for treachery
# found treachery in model
# count is now 17.0
# looking for dissent
# found dissent in model
# count is now 18.0
# looking for dishonor
# found dishonor in model
# count is now 19.0
# looking for dissension
# found dissension in model
# count is now 20.0
# looking for disrespects
# found disrespects in model
# count is now 21.0
# looking for bedlam
# found bedlam in model
# count is now 22.0
# looking for rebelling
# found rebelling in model
# count is now 23.0
# looking for misrule
# found misrule in model
# count is now 24.0
# looking for transgression
# found transgression in model
# count is now 25.0
# looking for insurrectional
# found insurrectional in model
# count is now 26.0
# looking for pandemonium
# found pandemonium in model
# count is now 27.0
# looking for mutiny
# found mutiny in model
# count is now 28.0
# looking for mutinies
# found mutinies in model
# count is now 29.0
# looking for misruling
# found misruling in model
# count is now 30.0
# looking for disobedient
# found disobedient in model
# count is now 31.0
# looking for subverted
# found subverted in model
# count is now 32.0
# looking for transgresses
# found transgresses in model
# count is now 33.0
# looking for transgressed
# found transgressed in model
# count is now 34.0
# looking for disarray
# found disarray in model
# count is now 35.0
# looking for misruled
# found misruled in model
# count is now 36.0
# looking for rioting
# found rioting in model
# count is now 37.0
# looking for lawless
# found lawless in model
# count is now 38.0
# looking for transgressing
# found transgressing in model
# count is now 39.0
# looking for illegality
# found illegality in model
# count is now 40.0
# looking for overthrowing
# found overthrowing in model
# count is now 41.0
# looking for dishonorable
# found dishonorable in model
# count is now 42.0
# looking for dishonoring
# found dishonoring in model
# count is now 43.0
# looking for rebelled
# found rebelled in model
# count is now 44.0
# looking for rebellions
# found rebellions in model
# count is now 45.0
# looking for riot
# found riot in model
# count is now 46.0
# looking for dishonouring
# found dishonouring in model
# count is now 47.0
# looking for disrespected
# found disrespected in model
# count is now 48.0
# looking for permissiveness
# found permissiveness in model
# count is now 49.0
# looking for refuser
# found refuser in model
# count is now 50.0
# looking for unruly
# found unruly in model
# count is now 51.0
# looking for subverts
# found subverts in model
# count is now 52.0
# looking for unlawfulness
# found unlawfulness in model
# count is now 53.0
# looking for overthrown
# found overthrown in model
# count is now 54.0
# looking for anarchistic
# found anarchistic in model
# count is now 55.0
# looking for dishonours
# found dishonours in model
# count is now 56.0
# looking for riots
# found riots in model
# count is now 57.0
# looking for refuse
# found refuse in model
# count is now 58.0
# looking for chaotic
# found chaotic in model
# count is now 59.0
# looking for nonconformity
# found nonconformity in model
# count is now 60.0
# looking for dissenters
# found dissenters in model
# count is now 61.0
# looking for uprising
# found uprising in model
# count is now 62.0
# looking for insurrections
# found insurrections in model
# count is now 63.0
# looking for rioters
# found rioters in model
# count is now 64.0
# looking for disordering
# found disordering in model
# count is now 65.0
# looking for insubordinate
# found insubordinate in model
# count is now 66.0
# looking for mutinied
# found mutinied in model
# count is now 67.0
# looking for insurrectionist
# found insurrectionist in model
# count is now 68.0
# looking for unlawful
# found unlawful in model
# count is now 69.0
# looking for nonconformists
# found nonconformists in model
# count is now 70.0
# looking for heresy
# found heresy in model
# count is now 71.0
# looking for uprisings
# found uprisings in model
# count is now 72.0
# looking for dishonors
# found dishonors in model
# count is now 73.0
# looking for tumult
# found tumult in model
# count is now 74.0
# looking for overthrew
# found overthrew in model
# count is now 75.0
# looking for overthrows
# found overthrows in model
# count is now 76.0
# looking for rabble
# found rabble in model
# count is now 77.0
# looking for rousers
# found rousers in model
# count is now 78.0
# looking for renegade
# found renegade in model
# count is now 79.0
# looking for impolite
# found impolite in model
# count is now 80.0
# looking for renegades
# found renegades in model
# count is now 81.0
# looking for rabble
# found rabble in model
# count is now 82.0
# looking for rousing
# found rousing in model
# count is now 83.0
# looking for dishonored
# found dishonored in model
# count is now 84.0
# looking for illegal
# found illegal in model
# count is now 85.0
# looking for rioter
# found rioter in model
# count is now 86.0
# looking for mutinous
# found mutinous in model
# count is now 87.0
# looking for disarrayed
# found disarrayed in model
# count is now 88.0
# looking for apostates
# found apostates in model
# count is now 89.0
# looking for dissidents
# found dissidents in model
# count is now 90.0
# looking for anarchists
# found anarchists in model
# count is now 91.0
# looking for raise
# found raise in model
# count is now 92.0
# looking for hell
# found hell in model
# count is now 93.0
# looking for disorder
# found disorder in model
# count is now 94.0
# looking for refusers
# found refusers in model
# count is now 95.0
# looking for permissive
# found permissive in model
# count is now 96.0
# looking for apostate
# found apostate in model
# count is now 97.0
# looking for anarchist
# found anarchist in model
# count is now 98.0
# looking for treacherous
# found treacherous in model
# count is now 99.0
# looking for dissident
# found dissident in model
# count is now 100.0
# looking for raises
# found raises in model
# count is now 101.0
# looking for hell
# found hell in model
# count is now 102.0
# looking for disordered
# found disordered in model
# count is now 103.0
# looking for heretic
# found heretic in model
# count is now 104.0
# looking for overpower
# found overpower in model
# count is now 105.0
# looking for rabble
# found rabble in model
# count is now 106.0
# looking for rouser
# found rouser in model
# count is now 107.0
# looking for rebel
# found rebel in model
# count is now 108.0
# looking for raising
# found raising in model
# count is now 109.0
# looking for hell
# found hell in model
# count is now 110.0
# looking for heretics
# found heretics in model
# count is now 111.0
# looking for unauthorized
# found unauthorized in model
# count is now 112.0
# looking for refusing
# found refusing in model
# count is now 113.0
# looking for rebels
# found rebels in model
# count is now 114.0
# looking for refuses
# found refuses in model
# count is now 115.0
# looking for rioted
# found rioted in model
# count is now 116.0
# looking for orders
# found orders in model
# count is now 117.0
# looking for dissenter
# found dissenter in model
# count is now 118.0
# looking for chaotically
# found chaotically in model
# count is now 119.0
# looking for nonconformist
# found nonconformist in model
# count is now 120.0
# looking for heresies
# found heresies in model
# count is now 121.0
# looking for illegals
# found illegals in model
# count is now 122.0
# looking for unlawfully
# found unlawfully in model
# count is now 123.0
# looking for heretical
# found heretical in model
# count is now 124.0
# looking for dissents
# found dissents in model
# count is now 125.0
# looking for traditions
# found traditions in model
# count is now 126.0
# looking for dissenting
# found dissenting in model
# count is now 127.0
# looking for overpowers
# found overpowers in model
# count is now 128.0
# looking for trouble
# found trouble in model
# count is now 129.0
# looking for maker
# found maker in model
# count is now 130.0
# looking for refused
# found refused in model
# count is now 131.0
# looking for rock
# found rock in model
# count is now 132.0
# looking for the
# found the in model
# count is now 133.0
# looking for boat
# found boat in model
# count is now 134.0
# looking for overpowering
# found overpowering in model
# count is now 135.0
# looking for tumultuous
# found tumultuous in model
# count is now 136.0
# looking for overpowered
# found overpowered in model
# count is now 137.0
# looking for dissented
# found dissented in model
# count is now 138.0
# looking for nonconforming
# found nonconforming in model
# count is now 139.0
# doing care.virtue.txt; [b'compassion', b'empathy', b'kindness', b'caring', b'generosity', b'benevolence', b'altruism', b'compassionate', b'nurture', b'gentleness', b'nurturance', b'sympathy', b'nurturing', b'motherly', b'love', b'beneficence', b'empathize', b'helpfulness', b'loving', b'pity', b'mercy', b'nurturer', b'compassionately', b'nurturers', b'caringly', b'empathising', b'merciful', b'empathizing', b'nurtures', b'warmhearted', b'empathizers', b'protectiveness', b'nurtured', b'benevolent', b'mothering', b'cared', b'healing', b'empathises', b'humane', b'comfort', b'pitied', b'loved', b'altruist', b'cares', b'pitying', b'comforted', b'hug', b'comforting', b'consoling', b'empathizes', b'sympathize', b'care', b'caregiver', b'empathised', b'hugs', b'heal', b'generous', b'condolences', b'mothered', b'charitable', b'generously', b'pities', b'condolence', b'help', b'consolingly', b'solace', b'mother', b'healer', b'hospitality', b'charity', b'empathized', b'healers', b'pityingly', b'mothers', b'child', b'lovingly', b'parenting', b'rescuing', b'rescuer', b'loves', b'consoled', b'clothe', b'sympathizing', b'helping', b'shared', b'childhood', b'mommy', b'vulnerability', b'helpers', b'lover', b'hospitable', b'sharer', b'feeding', b'nursed', b'helper', b'safeness', b'nurses', b'protector', b'motherhood', b'alleviation', b'nursemaid', b'safeguard', b'protect', b'healthiness', b'protecters', b'patient', b'nurse', b'vulnerable', b'benefit', b'feed', b'childcare', b'rescuers', b'hugged', b'helpful', b'rescues', b'nursing', b'protecting', b'heals', b'childbearing', b'hugger', b'relief', b'healed', b'rescued', b'patients', b'share', b'rescue', b'healthy', b'hospitalise', b'hospitalising', b'hugging', b'nursery', b'healthier', b'sharing', b'helps', b'sympathizers', b'hospitalises', b'alleviating', b'wounded', b'wounds', b'hospitalize', b'alleviate', b'protective', b'protection', b'health', b'relieve', b'sympathizer', b'safety', b'beneficiary', b'helped', b'hospital', b'childbirth', b'benefits', b'healthcare', b'relievers', b'feeds', b'hospitalization', b'benefitting', b'relieving', b'safe', b'feeder', b'benefitted', b'hospitalized', b'unharmful', b'protects', b'unharmed', b'protecter', b'safely', b'safekeeping', b'hospitalizing', b'wounding', b'reliever', b'shares', b'relieves', b'alleviates', b'relieved', b'hospitalizes', b'console', b'protectorate', b'alleviated', b'protected', b'wound', b'consoles']
# looking for compassion
# found compassion in model
# count is now 1.0
# looking for empathy
# found empathy in model
# count is now 2.0
# looking for kindness
# found kindness in model
# count is now 3.0
# looking for caring
# found caring in model
# count is now 4.0
# looking for generosity
# found generosity in model
# count is now 5.0
# looking for benevolence
# found benevolence in model
# count is now 6.0
# looking for altruism
# found altruism in model
# count is now 7.0
# looking for compassionate
# found compassionate in model
# count is now 8.0
# looking for nurture
# found nurture in model
# count is now 9.0
# looking for gentleness
# found gentleness in model
# count is now 10.0
# looking for nurturance
# found nurturance in model
# count is now 11.0
# looking for sympathy
# found sympathy in model
# count is now 12.0
# looking for nurturing
# found nurturing in model
# count is now 13.0
# looking for motherly
# found motherly in model
# count is now 14.0
# looking for love
# found love in model
# count is now 15.0
# looking for beneficence
# found beneficence in model
# count is now 16.0
# looking for empathize
# found empathize in model
# count is now 17.0
# looking for helpfulness
# found helpfulness in model
# count is now 18.0
# looking for loving
# found loving in model
# count is now 19.0
# looking for pity
# found pity in model
# count is now 20.0
# looking for mercy
# found mercy in model
# count is now 21.0
# looking for nurturer
# found nurturer in model
# count is now 22.0
# looking for compassionately
# found compassionately in model
# count is now 23.0
# looking for nurturers
# found nurturers in model
# count is now 24.0
# looking for caringly
# found caringly in model
# count is now 25.0
# looking for empathising
# found empathising in model
# count is now 26.0
# looking for merciful
# found merciful in model
# count is now 27.0
# looking for empathizing
# found empathizing in model
# count is now 28.0
# looking for nurtures
# found nurtures in model
# count is now 29.0
# looking for warmhearted
# found warmhearted in model
# count is now 30.0
# looking for empathizers
# found empathizers in model
# count is now 31.0
# looking for protectiveness
# found protectiveness in model
# count is now 32.0
# looking for nurtured
# found nurtured in model
# count is now 33.0
# looking for benevolent
# found benevolent in model
# count is now 34.0
# looking for mothering
# found mothering in model
# count is now 35.0
# looking for cared
# found cared in model
# count is now 36.0
# looking for healing
# found healing in model
# count is now 37.0
# looking for empathises
# found empathises in model
# count is now 38.0
# looking for humane
# found humane in model
# count is now 39.0
# looking for comfort
# found comfort in model
# count is now 40.0
# looking for pitied
# found pitied in model
# count is now 41.0
# looking for loved
# found loved in model
# count is now 42.0
# looking for altruist
# found altruist in model
# count is now 43.0
# looking for cares
# found cares in model
# count is now 44.0
# looking for pitying
# found pitying in model
# count is now 45.0
# looking for comforted
# found comforted in model
# count is now 46.0
# looking for hug
# found hug in model
# count is now 47.0
# looking for comforting
# found comforting in model
# count is now 48.0
# looking for consoling
# found consoling in model
# count is now 49.0
# looking for empathizes
# found empathizes in model
# count is now 50.0
# looking for sympathize
# found sympathize in model
# count is now 51.0
# looking for care
# found care in model
# count is now 52.0
# looking for caregiver
# found caregiver in model
# count is now 53.0
# looking for empathised
# found empathised in model
# count is now 54.0
# looking for hugs
# found hugs in model
# count is now 55.0
# looking for heal
# found heal in model
# count is now 56.0
# looking for generous
# found generous in model
# count is now 57.0
# looking for condolences
# found condolences in model
# count is now 58.0
# looking for mothered
# found mothered in model
# count is now 59.0
# looking for charitable
# found charitable in model
# count is now 60.0
# looking for generously
# found generously in model
# count is now 61.0
# looking for pities
# found pities in model
# count is now 62.0
# looking for condolence
# found condolence in model
# count is now 63.0
# looking for help
# found help in model
# count is now 64.0
# looking for consolingly
# found consolingly in model
# count is now 65.0
# looking for solace
# found solace in model
# count is now 66.0
# looking for mother
# found mother in model
# count is now 67.0
# looking for healer
# found healer in model
# count is now 68.0
# looking for hospitality
# found hospitality in model
# count is now 69.0
# looking for charity
# found charity in model
# count is now 70.0
# looking for empathized
# found empathized in model
# count is now 71.0
# looking for healers
# found healers in model
# count is now 72.0
# looking for pityingly
# found pityingly in model
# count is now 73.0
# looking for mothers
# found mothers in model
# count is now 74.0
# looking for child
# found child in model
# count is now 75.0
# looking for lovingly
# found lovingly in model
# count is now 76.0
# looking for parenting
# found parenting in model
# count is now 77.0
# looking for rescuing
# found rescuing in model
# count is now 78.0
# looking for rescuer
# found rescuer in model
# count is now 79.0
# looking for loves
# found loves in model
# count is now 80.0
# looking for consoled
# found consoled in model
# count is now 81.0
# looking for clothe
# found clothe in model
# count is now 82.0
# looking for sympathizing
# found sympathizing in model
# count is now 83.0
# looking for helping
# found helping in model
# count is now 84.0
# looking for shared
# found shared in model
# count is now 85.0
# looking for childhood
# found childhood in model
# count is now 86.0
# looking for mommy
# found mommy in model
# count is now 87.0
# looking for vulnerability
# found vulnerability in model
# count is now 88.0
# looking for helpers
# found helpers in model
# count is now 89.0
# looking for lover
# found lover in model
# count is now 90.0
# looking for hospitable
# found hospitable in model
# count is now 91.0
# looking for sharer
# found sharer in model
# count is now 92.0
# looking for feeding
# found feeding in model
# count is now 93.0
# looking for nursed
# found nursed in model
# count is now 94.0
# looking for helper
# found helper in model
# count is now 95.0
# looking for safeness
# found safeness in model
# count is now 96.0
# looking for nurses
# found nurses in model
# count is now 97.0
# looking for protector
# found protector in model
# count is now 98.0
# looking for motherhood
# found motherhood in model
# count is now 99.0
# looking for alleviation
# found alleviation in model
# count is now 100.0
# looking for nursemaid
# found nursemaid in model
# count is now 101.0
# looking for safeguard
# found safeguard in model
# count is now 102.0
# looking for protect
# found protect in model
# count is now 103.0
# looking for healthiness
# found healthiness in model
# count is now 104.0
# looking for protecters
# found protecters in model
# count is now 105.0
# looking for patient
# found patient in model
# count is now 106.0
# looking for nurse
# found nurse in model
# count is now 107.0
# looking for vulnerable
# found vulnerable in model
# count is now 108.0
# looking for benefit
# found benefit in model
# count is now 109.0
# looking for feed
# found feed in model
# count is now 110.0
# looking for childcare
# found childcare in model
# count is now 111.0
# looking for rescuers
# found rescuers in model
# count is now 112.0
# looking for hugged
# found hugged in model
# count is now 113.0
# looking for helpful
# found helpful in model
# count is now 114.0
# looking for rescues
# found rescues in model
# count is now 115.0
# looking for nursing
# found nursing in model
# count is now 116.0
# looking for protecting
# found protecting in model
# count is now 117.0
# looking for heals
# found heals in model
# count is now 118.0
# looking for childbearing
# found childbearing in model
# count is now 119.0
# looking for hugger
# found hugger in model
# count is now 120.0
# looking for relief
# found relief in model
# count is now 121.0
# looking for healed
# found healed in model
# count is now 122.0
# looking for rescued
# found rescued in model
# count is now 123.0
# looking for patients
# found patients in model
# count is now 124.0
# looking for share
# found share in model
# count is now 125.0
# looking for rescue
# found rescue in model
# count is now 126.0
# looking for healthy
# found healthy in model
# count is now 127.0
# looking for hospitalise
# found hospitalise in model
# count is now 128.0
# looking for hospitalising
# found hospitalising in model
# count is now 129.0
# looking for hugging
# found hugging in model
# count is now 130.0
# looking for nursery
# found nursery in model
# count is now 131.0
# looking for healthier
# found healthier in model
# count is now 132.0
# looking for sharing
# found sharing in model
# count is now 133.0
# looking for helps
# found helps in model
# count is now 134.0
# looking for sympathizers
# found sympathizers in model
# count is now 135.0
# looking for hospitalises
# found hospitalises in model
# count is now 136.0
# looking for alleviating
# found alleviating in model
# count is now 137.0
# looking for wounded
# found wounded in model
# count is now 138.0
# looking for wounds
# found wounds in model
# count is now 139.0
# looking for hospitalize
# found hospitalize in model
# count is now 140.0
# looking for alleviate
# found alleviate in model
# count is now 141.0
# looking for protective
# found protective in model
# count is now 142.0
# looking for protection
# found protection in model
# count is now 143.0
# looking for health
# found health in model
# count is now 144.0
# looking for relieve
# found relieve in model
# count is now 145.0
# looking for sympathizer
# found sympathizer in model
# count is now 146.0
# looking for safety
# found safety in model
# count is now 147.0
# looking for beneficiary
# found beneficiary in model
# count is now 148.0
# looking for helped
# found helped in model
# count is now 149.0
# looking for hospital
# found hospital in model
# count is now 150.0
# looking for childbirth
# found childbirth in model
# count is now 151.0
# looking for benefits
# found benefits in model
# count is now 152.0
# looking for healthcare
# found healthcare in model
# count is now 153.0
# looking for relievers
# found relievers in model
# count is now 154.0
# looking for feeds
# found feeds in model
# count is now 155.0
# looking for hospitalization
# found hospitalization in model
# count is now 156.0
# looking for benefitting
# found benefitting in model
# count is now 157.0
# looking for relieving
# found relieving in model
# count is now 158.0
# looking for safe
# found safe in model
# count is now 159.0
# looking for feeder
# found feeder in model
# count is now 160.0
# looking for benefitted
# found benefitted in model
# count is now 161.0
# looking for hospitalized
# found hospitalized in model
# count is now 162.0
# looking for unharmful
# found unharmful in model
# count is now 163.0
# looking for protects
# found protects in model
# count is now 164.0
# looking for unharmed
# found unharmed in model
# count is now 165.0
# looking for protecter
# found protecter in model
# count is now 166.0
# looking for safely
# found safely in model
# count is now 167.0
# looking for safekeeping
# found safekeeping in model
# count is now 168.0
# looking for hospitalizing
# found hospitalizing in model
# count is now 169.0
# looking for wounding
# found wounding in model
# count is now 170.0
# looking for reliever
# found reliever in model
# count is now 171.0
# looking for shares
# found shares in model
# count is now 172.0
# looking for relieves
# found relieves in model
# count is now 173.0
# looking for alleviates
# found alleviates in model
# count is now 174.0
# looking for relieved
# found relieved in model
# count is now 175.0
# looking for hospitalizes
# found hospitalizes in model
# count is now 176.0
# looking for console
# found console in model
# count is now 177.0
# looking for protectorate
# found protectorate in model
# count is now 178.0
# looking for alleviated
# found alleviated in model
# count is now 179.0
# looking for protected
# found protected in model
# count is now 180.0
# looking for wound
# found wound in model
# count is now 181.0
# looking for consoles
# found consoles in model
# count is now 182.0
# doing fairness.virtue.txt; [b'equality', b'fairness', b'justice', b'rights', b'equitable', b'civil', b'rights', b'fairplay', b'impartiality', b'equal', b'fairminded', b'proportionality', b'equalities', b'fair', b'integrity', b'impartial', b'reciprocity', b'honesty', b'egalitarian', b'civil', b'right', b'law', b'justness', b'unbias', b'egalitarians', b'parity', b'objectiveness', b'reparations', b'unprejudiced', b'justices', b'laws', b'tribunals', b'retribution', b'reparation', b'lawfully', b'lawful', b'honest', b'compensation', b'lawyers', b'sportsmanship', b'tribunal', b'do', b'unto', b'others', b'golden', b'rule', b'lawyer', b'proportional', b'equity', b'lawyering', b'trust', b'reciprocal', b'being', b'objective', b'justification', b'trustworthiness', b'unbiased', b'vengeance', b'revenge', b'retributions', b'equals', b'equalize', b'refereeing', b'restitution', b'compensating', b'been', b'objective', b'pay', b'back', b'justified', b'justifies', b'retaliation', b'lawyered', b'compensated', b'referees', b'karma', b'will', b'share', b'avenger', b'trusting', b'avengers', b'square', b'deal', b'trusts', b'compensate', b'trustworthy', b'levels', b'the', b'playing', b'field', b'tit', b'for', b'tat', b'retaliate', b'level', b'the', b'playing', b'field', b'eye', b'for', b'an', b'eye', b'square', b'deals', b'repayment', b'payback', b'equities', b'justify', b'dues', b'square', b'dealing', b'referee', b'repaid', b'square', b'dealer', b'equalizer', b'due', b'processes', b'level', b'playing', b'fields', b'repay', b'compensates', b'justifying', b'due', b'processing', b'due', b'process', b'repayments', b'repaying', b'level', b'playing', b'field', b'retaliating', b'square', b'dealers', b'retaliated', b'refereed', b'revenger', b'avenging', b'repays', b'trusted', b'avenge', b'retaliates', b'equalizers', b'avenged', b'avenges']
# looking for equality
# found equality in model
# count is now 1.0
# looking for fairness
# found fairness in model
# count is now 2.0
# looking for justice
# found justice in model
# count is now 3.0
# looking for rights
# found rights in model
# count is now 4.0
# looking for equitable
# found equitable in model
# count is now 5.0
# looking for civil
# found civil in model
# count is now 6.0
# looking for rights
# found rights in model
# count is now 7.0
# looking for fairplay
# found fairplay in model
# count is now 8.0
# looking for impartiality
# found impartiality in model
# count is now 9.0
# looking for equal
# found equal in model
# count is now 10.0
# looking for fairminded
# found fairminded in model
# count is now 11.0
# looking for proportionality
# found proportionality in model
# count is now 12.0
# looking for equalities
# found equalities in model
# count is now 13.0
# looking for fair
# found fair in model
# count is now 14.0
# looking for integrity
# found integrity in model
# count is now 15.0
# looking for impartial
# found impartial in model
# count is now 16.0
# looking for reciprocity
# found reciprocity in model
# count is now 17.0
# looking for honesty
# found honesty in model
# count is now 18.0
# looking for egalitarian
# found egalitarian in model
# count is now 19.0
# looking for civil
# found civil in model
# count is now 20.0
# looking for right
# found right in model
# count is now 21.0
# looking for law
# found law in model
# count is now 22.0
# looking for justness
# found justness in model
# count is now 23.0
# looking for unbias
# found unbias in model
# count is now 24.0
# looking for egalitarians
# found egalitarians in model
# count is now 25.0
# looking for parity
# found parity in model
# count is now 26.0
# looking for objectiveness
# found objectiveness in model
# count is now 27.0
# looking for reparations
# found reparations in model
# count is now 28.0
# looking for unprejudiced
# found unprejudiced in model
# count is now 29.0
# looking for justices
# found justices in model
# count is now 30.0
# looking for laws
# found laws in model
# count is now 31.0
# looking for tribunals
# found tribunals in model
# count is now 32.0
# looking for retribution
# found retribution in model
# count is now 33.0
# looking for reparation
# found reparation in model
# count is now 34.0
# looking for lawfully
# found lawfully in model
# count is now 35.0
# looking for lawful
# found lawful in model
# count is now 36.0
# looking for honest
# found honest in model
# count is now 37.0
# looking for compensation
# found compensation in model
# count is now 38.0
# looking for lawyers
# found lawyers in model
# count is now 39.0
# looking for sportsmanship
# found sportsmanship in model
# count is now 40.0
# looking for tribunal
# found tribunal in model
# count is now 41.0
# looking for do
# found do in model
# count is now 42.0
# looking for unto
# found unto in model
# count is now 43.0
# looking for others
# found others in model
# count is now 44.0
# looking for golden
# found golden in model
# count is now 45.0
# looking for rule
# found rule in model
# count is now 46.0
# looking for lawyer
# found lawyer in model
# count is now 47.0
# looking for proportional
# found proportional in model
# count is now 48.0
# looking for equity
# found equity in model
# count is now 49.0
# looking for lawyering
# found lawyering in model
# count is now 50.0
# looking for trust
# found trust in model
# count is now 51.0
# looking for reciprocal
# found reciprocal in model
# count is now 52.0
# looking for being
# found being in model
# count is now 53.0
# looking for objective
# found objective in model
# count is now 54.0
# looking for justification
# found justification in model
# count is now 55.0
# looking for trustworthiness
# found trustworthiness in model
# count is now 56.0
# looking for unbiased
# found unbiased in model
# count is now 57.0
# looking for vengeance
# found vengeance in model
# count is now 58.0
# looking for revenge
# found revenge in model
# count is now 59.0
# looking for retributions
# found retributions in model
# count is now 60.0
# looking for equals
# found equals in model
# count is now 61.0
# looking for equalize
# found equalize in model
# count is now 62.0
# looking for refereeing
# found refereeing in model
# count is now 63.0
# looking for restitution
# found restitution in model
# count is now 64.0
# looking for compensating
# found compensating in model
# count is now 65.0
# looking for been
# found been in model
# count is now 66.0
# looking for objective
# found objective in model
# count is now 67.0
# looking for pay
# found pay in model
# count is now 68.0
# looking for back
# found back in model
# count is now 69.0
# looking for justified
# found justified in model
# count is now 70.0
# looking for justifies
# found justifies in model
# count is now 71.0
# looking for retaliation
# found retaliation in model
# count is now 72.0
# looking for lawyered
# found lawyered in model
# count is now 73.0
# looking for compensated
# found compensated in model
# count is now 74.0
# looking for referees
# found referees in model
# count is now 75.0
# looking for karma
# found karma in model
# count is now 76.0
# looking for will
# found will in model
# count is now 77.0
# looking for share
# found share in model
# count is now 78.0
# looking for avenger
# found avenger in model
# count is now 79.0
# looking for trusting
# found trusting in model
# count is now 80.0
# looking for avengers
# found avengers in model
# count is now 81.0
# looking for square
# found square in model
# count is now 82.0
# looking for deal
# found deal in model
# count is now 83.0
# looking for trusts
# found trusts in model
# count is now 84.0
# looking for compensate
# found compensate in model
# count is now 85.0
# looking for trustworthy
# found trustworthy in model
# count is now 86.0
# looking for levels
# found levels in model
# count is now 87.0
# looking for the
# found the in model
# count is now 88.0
# looking for playing
# found playing in model
# count is now 89.0
# looking for field
# found field in model
# count is now 90.0
# looking for tit
# found tit in model
# count is now 91.0
# looking for for
# found for in model
# count is now 92.0
# looking for tat
# found tat in model
# count is now 93.0
# looking for retaliate
# found retaliate in model
# count is now 94.0
# looking for level
# found level in model
# count is now 95.0
# looking for the
# found the in model
# count is now 96.0
# looking for playing
# found playing in model
# count is now 97.0
# looking for field
# found field in model
# count is now 98.0
# looking for eye
# found eye in model
# count is now 99.0
# looking for for
# found for in model
# count is now 100.0
# looking for an
# found an in model
# count is now 101.0
# looking for eye
# found eye in model
# count is now 102.0
# looking for square
# found square in model
# count is now 103.0
# looking for deals
# found deals in model
# count is now 104.0
# looking for repayment
# found repayment in model
# count is now 105.0
# looking for payback
# found payback in model
# count is now 106.0
# looking for equities
# found equities in model
# count is now 107.0
# looking for justify
# found justify in model
# count is now 108.0
# looking for dues
# found dues in model
# count is now 109.0
# looking for square
# found square in model
# count is now 110.0
# looking for dealing
# found dealing in model
# count is now 111.0
# looking for referee
# found referee in model
# count is now 112.0
# looking for repaid
# found repaid in model
# count is now 113.0
# looking for square
# found square in model
# count is now 114.0
# looking for dealer
# found dealer in model
# count is now 115.0
# looking for equalizer
# found equalizer in model
# count is now 116.0
# looking for due
# found due in model
# count is now 117.0
# looking for processes
# found processes in model
# count is now 118.0
# looking for level
# found level in model
# count is now 119.0
# looking for playing
# found playing in model
# count is now 120.0
# looking for fields
# found fields in model
# count is now 121.0
# looking for repay
# found repay in model
# count is now 122.0
# looking for compensates
# found compensates in model
# count is now 123.0
# looking for justifying
# found justifying in model
# count is now 124.0
# looking for due
# found due in model
# count is now 125.0
# looking for processing
# found processing in model
# count is now 126.0
# looking for due
# found due in model
# count is now 127.0
# looking for process
# found process in model
# count is now 128.0
# looking for repayments
# found repayments in model
# count is now 129.0
# looking for repaying
# found repaying in model
# count is now 130.0
# looking for level
# found level in model
# count is now 131.0
# looking for playing
# found playing in model
# count is now 132.0
# looking for field
# found field in model
# count is now 133.0
# looking for retaliating
# found retaliating in model
# count is now 134.0
# looking for square
# found square in model
# count is now 135.0
# looking for dealers
# found dealers in model
# count is now 136.0
# looking for retaliated
# found retaliated in model
# count is now 137.0
# looking for refereed
# found refereed in model
# count is now 138.0
# looking for revenger
# found revenger in model
# count is now 139.0
# looking for avenging
# found avenging in model
# count is now 140.0
# looking for repays
# found repays in model
# count is now 141.0
# looking for trusted
# found trusted in model
# count is now 142.0
# looking for avenge
# found avenge in model
# count is now 143.0
# looking for retaliates
# found retaliates in model
# count is now 144.0
# looking for equalizers
# found equalizers in model
# count is now 145.0
# looking for avenged
# found avenged in model
# count is now 146.0
# looking for avenges
# found avenges in model
# count is now 147.0
# doing loyalty.virtue.txt; [b'team', b'player', b'player', b'patriot', b'loyal', b'loyalty', b'patriots', b'follower', b'fidelity', b'allegiance', b'ally', b'comrade', b'loyalties', b'death', b'do', b'us', b'part', b'faction', b'comrades', b'allegiances', b'sacrifice', b'allies', b'organization', b'followers', b'us', b'against', b'them', b'sacrifices', b'all', b'for', b'one', b'camaraderie', b'comradery', b'one', b'for', b'all', b'fellow', b'family', b'allegiant', b'corps', b'unity', b'union', b'jack', b'uniter', b'old', b'glory', b'companions', b'country', b'companion', b'homeland', b'sacrificing', b'indivisible', b'sacrificed', b'solidarity', b'troops', b'nation', b'cult', b'kinship', b'companionship', b'clique', b'allied', b'community', b'group', b'factions', b'familiarity', b'solidarities', b'enlist', b'companionships', b'wife', b'united', b'belongs', b'congregation', b'brothers', b'in', b'arms', b'clan', b'trooper', b'sect', b'enlisted', b'enlistment', b'tribalism', b'cohorts', b'war', b'joining', b'troop', b'sacrificial', b'coalition', b'insider', b'pledge', b'cohort', b'enlisting', b'unite', b'communion', b'familiarities', b'belong', b'ingroup', b'belonged', b'company', b'collective', b'fellows', b'cliques', b'uniting', b'clans', b'hazing', b'congregates', b'herd', b'sects', b'uniters', b'undivided', b'unites', b'pledgers', b'coalitions', b'enlists', b'grouping', b'insiders', b'families', b'troupe', b'fellowship', b'kin', b'pledger', b'horde', b'nations', b'tribe', b'hordes', b'pledges', b'herder', b'commune', b'cults', b'congregations', b'organizations', b'herds', b'pledging', b'communities', b'familiar', b'hazings', b'belonging', b'pledged', b'bowed', b'collectively', b'together', b'groups', b'homelands', b'collectives', b'troopers', b'tribes', b'companies', b'countries', b'troupes', b'fellowships', b'tribal', b'communes', b'herders', b'grouped', b'herding', b'congregate', b'herded', b'congregating']
# looking for team
# found team in model
# count is now 1.0
# looking for player
# found player in model
# count is now 2.0
# looking for player
# found player in model
# count is now 3.0
# looking for patriot
# found patriot in model
# count is now 4.0
# looking for loyal
# found loyal in model
# count is now 5.0
# looking for loyalty
# found loyalty in model
# count is now 6.0
# looking for patriots
# found patriots in model
# count is now 7.0
# looking for follower
# found follower in model
# count is now 8.0
# looking for fidelity
# found fidelity in model
# count is now 9.0
# looking for allegiance
# found allegiance in model
# count is now 10.0
# looking for ally
# found ally in model
# count is now 11.0
# looking for comrade
# found comrade in model
# count is now 12.0
# looking for loyalties
# found loyalties in model
# count is now 13.0
# looking for death
# found death in model
# count is now 14.0
# looking for do
# found do in model
# count is now 15.0
# looking for us
# found us in model
# count is now 16.0
# looking for part
# found part in model
# count is now 17.0
# looking for faction
# found faction in model
# count is now 18.0
# looking for comrades
# found comrades in model
# count is now 19.0
# looking for allegiances
# found allegiances in model
# count is now 20.0
# looking for sacrifice
# found sacrifice in model
# count is now 21.0
# looking for allies
# found allies in model
# count is now 22.0
# looking for organization
# found organization in model
# count is now 23.0
# looking for followers
# found followers in model
# count is now 24.0
# looking for us
# found us in model
# count is now 25.0
# looking for against
# found against in model
# count is now 26.0
# looking for them
# found them in model
# count is now 27.0
# looking for sacrifices
# found sacrifices in model
# count is now 28.0
# looking for all
# found all in model
# count is now 29.0
# looking for for
# found for in model
# count is now 30.0
# looking for one
# found one in model
# count is now 31.0
# looking for camaraderie
# found camaraderie in model
# count is now 32.0
# looking for comradery
# found comradery in model
# count is now 33.0
# looking for one
# found one in model
# count is now 34.0
# looking for for
# found for in model
# count is now 35.0
# looking for all
# found all in model
# count is now 36.0
# looking for fellow
# found fellow in model
# count is now 37.0
# looking for family
# found family in model
# count is now 38.0
# looking for allegiant
# found allegiant in model
# count is now 39.0
# looking for corps
# found corps in model
# count is now 40.0
# looking for unity
# found unity in model
# count is now 41.0
# looking for union
# found union in model
# count is now 42.0
# looking for jack
# found jack in model
# count is now 43.0
# looking for uniter
# found uniter in model
# count is now 44.0
# looking for old
# found old in model
# count is now 45.0
# looking for glory
# found glory in model
# count is now 46.0
# looking for companions
# found companions in model
# count is now 47.0
# looking for country
# found country in model
# count is now 48.0
# looking for companion
# found companion in model
# count is now 49.0
# looking for homeland
# found homeland in model
# count is now 50.0
# looking for sacrificing
# found sacrificing in model
# count is now 51.0
# looking for indivisible
# found indivisible in model
# count is now 52.0
# looking for sacrificed
# found sacrificed in model
# count is now 53.0
# looking for solidarity
# found solidarity in model
# count is now 54.0
# looking for troops
# found troops in model
# count is now 55.0
# looking for nation
# found nation in model
# count is now 56.0
# looking for cult
# found cult in model
# count is now 57.0
# looking for kinship
# found kinship in model
# count is now 58.0
# looking for companionship
# found companionship in model
# count is now 59.0
# looking for clique
# found clique in model
# count is now 60.0
# looking for allied
# found allied in model
# count is now 61.0
# looking for community
# found community in model
# count is now 62.0
# looking for group
# found group in model
# count is now 63.0
# looking for factions
# found factions in model
# count is now 64.0
# looking for familiarity
# found familiarity in model
# count is now 65.0
# looking for solidarities
# found solidarities in model
# count is now 66.0
# looking for enlist
# found enlist in model
# count is now 67.0
# looking for companionships
# found companionships in model
# count is now 68.0
# looking for wife
# found wife in model
# count is now 69.0
# looking for united
# found united in model
# count is now 70.0
# looking for belongs
# found belongs in model
# count is now 71.0
# looking for congregation
# found congregation in model
# count is now 72.0
# looking for brothers
# found brothers in model
# count is now 73.0
# looking for in
# found in in model
# count is now 74.0
# looking for arms
# found arms in model
# count is now 75.0
# looking for clan
# found clan in model
# count is now 76.0
# looking for trooper
# found trooper in model
# count is now 77.0
# looking for sect
# found sect in model
# count is now 78.0
# looking for enlisted
# found enlisted in model
# count is now 79.0
# looking for enlistment
# found enlistment in model
# count is now 80.0
# looking for tribalism
# found tribalism in model
# count is now 81.0
# looking for cohorts
# found cohorts in model
# count is now 82.0
# looking for war
# found war in model
# count is now 83.0
# looking for joining
# found joining in model
# count is now 84.0
# looking for troop
# found troop in model
# count is now 85.0
# looking for sacrificial
# found sacrificial in model
# count is now 86.0
# looking for coalition
# found coalition in model
# count is now 87.0
# looking for insider
# found insider in model
# count is now 88.0
# looking for pledge
# found pledge in model
# count is now 89.0
# looking for cohort
# found cohort in model
# count is now 90.0
# looking for enlisting
# found enlisting in model
# count is now 91.0
# looking for unite
# found unite in model
# count is now 92.0
# looking for communion
# found communion in model
# count is now 93.0
# looking for familiarities
# found familiarities in model
# count is now 94.0
# looking for belong
# found belong in model
# count is now 95.0
# looking for ingroup
# found ingroup in model
# count is now 96.0
# looking for belonged
# found belonged in model
# count is now 97.0
# looking for company
# found company in model
# count is now 98.0
# looking for collective
# found collective in model
# count is now 99.0
# looking for fellows
# found fellows in model
# count is now 100.0
# looking for cliques
# found cliques in model
# count is now 101.0
# looking for uniting
# found uniting in model
# count is now 102.0
# looking for clans
# found clans in model
# count is now 103.0
# looking for hazing
# found hazing in model
# count is now 104.0
# looking for congregates
# found congregates in model
# count is now 105.0
# looking for herd
# found herd in model
# count is now 106.0
# looking for sects
# found sects in model
# count is now 107.0
# looking for uniters
# found uniters in model
# count is now 108.0
# looking for undivided
# found undivided in model
# count is now 109.0
# looking for unites
# found unites in model
# count is now 110.0
# looking for pledgers
# found pledgers in model
# count is now 111.0
# looking for coalitions
# found coalitions in model
# count is now 112.0
# looking for enlists
# found enlists in model
# count is now 113.0
# looking for grouping
# found grouping in model
# count is now 114.0
# looking for insiders
# found insiders in model
# count is now 115.0
# looking for families
# found families in model
# count is now 116.0
# looking for troupe
# found troupe in model
# count is now 117.0
# looking for fellowship
# found fellowship in model
# count is now 118.0
# looking for kin
# found kin in model
# count is now 119.0
# looking for pledger
# found pledger in model
# count is now 120.0
# looking for horde
# found horde in model
# count is now 121.0
# looking for nations
# found nations in model
# count is now 122.0
# looking for tribe
# found tribe in model
# count is now 123.0
# looking for hordes
# found hordes in model
# count is now 124.0
# looking for pledges
# found pledges in model
# count is now 125.0
# looking for herder
# found herder in model
# count is now 126.0
# looking for commune
# found commune in model
# count is now 127.0
# looking for cults
# found cults in model
# count is now 128.0
# looking for congregations
# found congregations in model
# count is now 129.0
# looking for organizations
# found organizations in model
# count is now 130.0
# looking for herds
# found herds in model
# count is now 131.0
# looking for pledging
# found pledging in model
# count is now 132.0
# looking for communities
# found communities in model
# count is now 133.0
# looking for familiar
# found familiar in model
# count is now 134.0
# looking for hazings
# found hazings in model
# count is now 135.0
# looking for belonging
# found belonging in model
# count is now 136.0
# looking for pledged
# found pledged in model
# count is now 137.0
# looking for bowed
# found bowed in model
# count is now 138.0
# looking for collectively
# found collectively in model
# count is now 139.0
# looking for together
# found together in model
# count is now 140.0
# looking for groups
# found groups in model
# count is now 141.0
# looking for homelands
# found homelands in model
# count is now 142.0
# looking for collectives
# found collectives in model
# count is now 143.0
# looking for troopers
# found troopers in model
# count is now 144.0
# looking for tribes
# found tribes in model
# count is now 145.0
# looking for companies
# found companies in model
# count is now 146.0
# looking for countries
# found countries in model
# count is now 147.0
# looking for troupes
# found troupes in model
# count is now 148.0
# looking for fellowships
# found fellowships in model
# count is now 149.0
# looking for tribal
# found tribal in model
# count is now 150.0
# looking for communes
# found communes in model
# count is now 151.0
# looking for herders
# found herders in model
# count is now 152.0
# looking for grouped
# found grouped in model
# count is now 153.0
# looking for herding
# found herding in model
# count is now 154.0
# looking for congregate
# found congregate in model
# count is now 155.0
# looking for herded
# found herded in model
# count is now 156.0
# looking for congregating
# found congregating in model
# count is now 157.0
# ...
# count is now 81.0
# looking for lionize
# found lionize in model
# count is now 82.0
# looking for supervision
# found supervision in model
# count is now 83.0
# looking for take
# found take in model
# count is now 84.0
# looking for orders
# found orders in model
# count is now 85.0
# looking for take
# found take in model
# count is now 86.0
# looking for up
# found up in model
# count is now 87.0
# looking for arms
# found arms in model
# count is now 88.0
# looking for duties
# found duties in model
# count is now 89.0
# looking for dictated
# found dictated in model
# count is now 90.0
# looking for elders
# found elders in model
# count is now 91.0
# looking for emperors
# found emperors in model
# count is now 92.0
# looking for commands
# found commands in model
# count is now 93.0
# looking for acquiesced
# found acquiesced in model
# count is now 94.0
# looking for emperor
# found emperor in model
# count is now 95.0
# looking for adheres
# found adheres in model
# count is now 96.0
# looking for servants
# found servants in model
# count is now 97.0
# looking for regulations
# found regulations in model
# count is now 98.0
# looking for covenant
# found covenant in model
# count is now 99.0
# looking for hierarchical
# found hierarchical in model
# count is now 100.0
# looking for subordinate
# found subordinate in model
# count is now 101.0
# looking for policing
# found policing in model
# count is now 102.0
# looking for decreeing
# found decreeing in model
# count is now 103.0
# looking for acquiesces
# found acquiesces in model
# count is now 104.0
# looking for authorizing
# found authorizing in model
# count is now 105.0
# looking for nobles
# found nobles in model
# count is now 106.0
# looking for permits
# found permits in model
# count is now 107.0
# looking for matriarchal
# found matriarchal in model
# count is now 108.0
# looking for authorizes
# found authorizes in model
# count is now 109.0
# looking for control
# found control in model
# count is now 110.0
# looking for command
# found command in model
# count is now 111.0
# looking for subordinating
# found subordinating in model
# count is now 112.0
# looking for hierarchies
# found hierarchies in model
# count is now 113.0
# looking for reverential
# found reverential in model
# count is now 114.0
# looking for deferentially
# found deferentially in model
# count is now 115.0
# looking for punishes
# found punishes in model
# count is now 116.0
# looking for patriarch
# found patriarch in model
# count is now 117.0
# looking for empires
# found empires in model
# count is now 118.0
# looking for honored
# found honored in model
# count is now 119.0
# looking for allegiant
# found allegiant in model
# count is now 120.0
# looking for protect
# found protect in model
# count is now 121.0
# looking for traditional
# found traditional in model
# count is now 122.0
# looking for subordination
# found subordination in model
# count is now 123.0
# looking for punished
# found punished in model
# count is now 124.0
# looking for noble
# found noble in model
# count is now 125.0
# looking for order
# found order in model
# count is now 126.0
# looking for worship
# found worship in model
# count is now 127.0
# looking for social
# found social in model
# count is now 128.0
# looking for order
# found order in model
# count is now 129.0
# looking for monarchs
# found monarchs in model
# count is now 130.0
# looking for ruling
# found ruling in model
# count is now 131.0
# looking for lead
# found lead in model
# count is now 132.0
# looking for by
# found by in model
# count is now 133.0
# looking for example
# found example in model
# count is now 134.0
# looking for authorities
# found authorities in model
# count is now 135.0
# looking for guiding
# found guiding in model
# count is now 136.0
# looking for presidents
# found presidents in model
# count is now 137.0
# looking for slavishly
# found slavishly in model
# count is now 138.0
# looking for patriarchy
# found patriarchy in model
# count is now 139.0
# looking for subordinates
# found subordinates in model
# count is now 140.0
# looking for protection
# found protection in model
# count is now 141.0
# looking for supervisers
# found supervisers in model
# count is now 142.0
# looking for bow
# found bow in model
# count is now 143.0
# looking for before
# found before in model
# count is now 144.0
# looking for fathers
# found fathers in model
# count is now 145.0
# looking for bow
# found bow in model
# count is now 146.0
# looking for down
# found down in model
# count is now 147.0
# looking for institutions
# found institutions in model
# count is now 148.0
# looking for coercion
# found coercion in model
# count is now 149.0
# looking for governors
# found governors in model
# count is now 150.0
# looking for commanded
# found commanded in model
# count is now 151.0
# looking for police
# found police in model
# count is now 152.0
# looking for authorize
# found authorize in model
# count is now 153.0
# looking for bullys
# found bullys in model
# count is now 154.0
# looking for bully
# found bully in model
# count is now 155.0
# looking for protecting
# found protecting in model
# count is now 156.0
# looking for acquiescing
# found acquiescing in model
# count is now 157.0
# looking for empire
# found empire in model
# count is now 158.0
# looking for mentor
# found mentor in model
# count is now 159.0
# looking for chiefs
# found chiefs in model
# count is now 160.0
# looking for monarchies
# found monarchies in model
# count is now 161.0
# looking for honors
# found honors in model
# count is now 162.0
# looking for preside
# found preside in model
# count is now 163.0
# looking for over
# found over in model
# count is now 164.0
# looking for acquiescent
# found acquiescent in model
# count is now 165.0
# looking for allegiances
# found allegiances in model
# count is now 166.0
# looking for bowing
# found bowing in model
# count is now 167.0
# looking for oligarchy
# found oligarchy in model
# count is now 168.0
# looking for willing
# found willing in model
# count is now 169.0
# looking for polite
# found polite in model
# count is now 170.0
# looking for supervising
# found supervising in model
# count is now 171.0
# looking for pecking
# found pecking in model
# count is now 172.0
# looking for order
# found order in model
# count is now 173.0
# looking for compliantly
# found compliantly in model
# count is now 174.0
# looking for bishops
# found bishops in model
# count is now 175.0
# looking for monarch
# found monarch in model
# count is now 176.0
# looking for slaves
# found slaves in model
# count is now 177.0
# looking for traitors
# found traitors in model
# count is now 178.0
# looking for punishments
# found punishments in model
# count is now 179.0
# looking for authorized
# found authorized in model
# count is now 180.0
# looking for protector
# found protector in model
# count is now 181.0
# looking for compliant
# found compliant in model
# count is now 182.0
# looking for dutiful
# found dutiful in model
# count is now 183.0
# looking for father
# found father in model
# count is now 184.0
# looking for punishment
# found punishment in model
# count is now 185.0
# looking for coerces
# found coerces in model
# count is now 186.0
# looking for toe
# found toe in model
# count is now 187.0
# looking for the
# found the in model
# count is now 188.0
# looking for line
# found line in model
# count is now 189.0
# looking for monarchy
# found monarchy in model
# count is now 190.0
# looking for obediently
# found obediently in model
# count is now 191.0
# looking for elder
# found elder in model
# count is now 192.0
# looking for oligarchies
# found oligarchies in model
# count is now 193.0
# looking for dictators
# found dictators in model
# count is now 194.0
# looking for leaders
# found leaders in model
# count is now 195.0
# looking for bishop
# found bishop in model
# count is now 196.0
# looking for lorded
# found lorded in model
# count is now 197.0
# looking for over
# found over in model
# count is now 198.0
# looking for worships
# found worships in model
# count is now 199.0
# looking for coercing
# found coercing in model
# count is now 200.0
# looking for protectors
# found protectors in model
# count is now 201.0
# looking for dictator
# found dictator in model
# count is now 202.0
# looking for protected
# found protected in model
# count is now 203.0
# looking for punishing
# found punishing in model
# count is now 204.0
# looking for traitor
# found traitor in model
# count is now 205.0
# looking for commanding
# found commanding in model
# count is now 206.0
# looking for coerced
# found coerced in model
# count is now 207.0
# looking for commanders
# found commanders in model
# count is now 208.0
# looking for pope
# found pope in model
# count is now 209.0
# looking for punitive
# found punitive in model
# count is now 210.0
# looking for underlings
# found underlings in model
# count is now 211.0
# looking for master
# found master in model
# count is now 212.0
# looking for subordinated
# found subordinated in model
# count is now 213.0
# looking for president
# found president in model
# count is now 214.0
# looking for in
# found in in model
# count is now 215.0
# looking for charge
# found charge in model
# count is now 216.0
# looking for matriarchy
# found matriarchy in model
# count is now 217.0
# looking for lionizing
# found lionizing in model
# count is now 218.0
# looking for slave
# found slave in model
# count is now 219.0
# looking for chief
# found chief in model
# count is now 220.0
# looking for covenants
# found covenants in model
# count is now 221.0
# looking for commander
# found commander in model
# count is now 222.0
# looking for matriarch
# found matriarch in model
# count is now 223.0
# looking for authorizer
# found authorizer in model
# count is now 224.0
# looking for guide
# found guide in model
# count is now 225.0
# looking for ordered
# found ordered in model
# count is now 226.0
# looking for supervised
# found supervised in model
# count is now 227.0
# looking for captains
# found captains in model
# count is now 228.0
# looking for punisher
# found punisher in model
# count is now 229.0
# looking for supervises
# found supervises in model
# count is now 230.0
# looking for bossing
# found bossing in model
# count is now 231.0
# looking for commandant
# found commandant in model
# count is now 232.0
# looking for governor
# found governor in model
# count is now 233.0
# looking for protects
# found protects in model
# count is now 234.0
# looking for admiral
# found admiral in model
# count is now 235.0
# looking for top
# found top in model
# count is now 236.0
# looking for gun
# found gun in model
# count is now 237.0
# looking for bowed
# found bowed in model
# count is now 238.0
# looking for dominate
# found dominate in model
# count is now 239.0
# looking for arrest
# found arrest in model
# count is now 240.0
# looking for mentored
# found mentored in model
# count is now 241.0
# looking for ordering
# found ordering in model
# count is now 242.0
# looking for submit
# found submit in model
# count is now 243.0
# looking for institutional
# found institutional in model
# count is now 244.0
# looking for prime
# found prime in model
# count is now 245.0
# looking for minister
# found minister in model
# count is now 246.0
# looking for lionizes
# found lionizes in model
# count is now 247.0
# looking for ranking
# found ranking in model
# count is now 248.0
# looking for boss
# found boss in model
# count is now 249.0
# looking for captain
# found captain in model
# count is now 250.0
# looking for by
# found by in model
# count is now 251.0
# looking for the
# found the in model
# count is now 252.0
# looking for book
# found book in model
# count is now 253.0
# looking for mentors
# found mentors in model
# count is now 254.0
# looking for bullies
# found bullies in model
# count is now 255.0
# looking for dominant
# found dominant in model
# count is now 256.0
# looking for arrested
# found arrested in model
# count is now 257.0
# looking for bossed
# found bossed in model
# count is now 258.0
# looking for leader
# found leader in model
# count is now 259.0
# looking for rank
# found rank in model
# count is now 260.0
# looking for arresting
# found arresting in model
# count is now 261.0
# looking for chieftain
# found chieftain in model
# count is now 262.0
# looking for prime
# found prime in model
# count is now 263.0
# looking for ministers
# found ministers in model
# count is now 264.0
# looking for regulation
# found regulation in model
# count is now 265.0
# looking for superviser
# found superviser in model
# count is now 266.0
# looking for dean
# found dean in model
# count is now 267.0
# looking for arrests
# found arrests in model
# count is now 268.0
# looking for punishers
# found punishers in model
# count is now 269.0
# looking for bullied
# found bullied in model
# count is now 270.0
# looking for matriarchs
# found matriarchs in model
# count is now 271.0
# looking for controlling
# found controlling in model
# count is now 272.0
# looking for managerial
# found managerial in model
# count is now 273.0
# looking for bosses
# found bosses in model
# count is now 274.0
# looking for ranks
# found ranks in model
# count is now 275.0
# looking for controls
# found controls in model
# count is now 276.0
# looking for dictation
# found dictation in model
# count is now 277.0
# looking for guides
# found guides in model
# count is now 278.0
# looking for oligarchs
# found oligarchs in model
# count is now 279.0
# looking for principals
# found principals in model
# count is now 280.0
# looking for top
# found top in model
# count is now 281.0
# looking for dog
# found dog in model
# count is now 282.0
# looking for admirals
# found admirals in model
# count is now 283.0
# looking for caste
# found caste in model
# count is now 284.0
# looking for captaining
# found captaining in model
# count is now 285.0
# looking for queen
# found queen in model
# count is now 286.0
# looking for mentoring
# found mentoring in model
# count is now 287.0
# looking for elderly
# found elderly in model
# count is now 288.0
# looking for castes
# found castes in model
# count is now 289.0
# looking for governess
# found governess in model
# count is now 290.0
# looking for captained
# found captained in model
# count is now 291.0
# looking for principal
# found principal in model
# count is now 292.0
# looking for bullying
# found bullying in model
# count is now 293.0
# looking for submission
# found submission in model
# count is now 294.0
# looking for dominated
# found dominated in model
# count is now 295.0
# looking for corporate
# found corporate in model
# count is now 296.0
# looking for ladders
# found ladders in model
# count is now 297.0
# looking for queens
# found queens in model
# count is now 298.0
# looking for underling
# found underling in model
# count is now 299.0
# looking for corporate
# found corporate in model
# count is now 300.0
# looking for ladder
# found ladder in model
# count is now 301.0
# looking for fathered
# found fathered in model
# count is now 302.0
# looking for dominates
# found dominates in model
# count is now 303.0
# looking for dominating
# found dominating in model
# count is now 304.0
# looking for presidential
# found presidential in model
# count is now 305.0
# looking for oligarch
# found oligarch in model
# count is now 306.0
# looking for controlled
# found controlled in model
# count is now 307.0
# looking for submits
# found submits in model
# count is now 308.0
# looking for submitting
# found submitting in model
# count is now 309.0
# looking for head
# found head in model
# count is now 310.0
# looking for honcho
# found honcho in model
# count is now 311.0
# looking for commandingly
# found commandingly in model
# count is now 312.0
# looking for vice
# found vice in model
# count is now 313.0
# looking for president
# found president in model
# count is now 314.0
# looking for slaving
# found slaving in model
# count is now 315.0
# looking for fathering
# found fathering in model
# count is now 316.0
# looking for slaved
# found slaved in model
# count is now 317.0
# looking for managers
# found managers in model
# count is now 318.0
# looking for forbiddingly
# found forbiddingly in model
# count is now 319.0
# looking for controllers
# found controllers in model
# count is now 320.0
# looking for submitted
# found submitted in model
# count is now 321.0
# looking for ringleaders
# found ringleaders in model
# count is now 322.0
# looking for ringleader
# found ringleader in model
# count is now 323.0
# looking for controller
# found controller in model
# count is now 324.0
# looking for ranked
# found ranked in model
# count is now 325.0
# looking for manager
# found manager in model
# count is now 326.0
# looking for prime
# found prime in model
# count is now 327.0
# looking for ministerial
# found ministerial in model
# count is now 328.0
# looking for submissions
# found submissions in model
# count is now 329.0
# looking for ceo
# found ceo in model
# count is now 330.0
# looking for punishingly
# found punishingly in model
# count is now 331.0
# looking for submitter
# found submitter in model
# count is now 332.0
# looking for submitters
# found submitters in model
# count is now 333.0

# %%
# write dictionary representations file in which header=dictionary names, cols=dictionary vector representation
ddr.write_dic_vecs(dic_vecs=agg_dic_vecs, 
                   output_path="./agg_dic_vecs_WTB.tsv")

# %% [markdown]
# # Generate document representations
# ddr can generate document representations for corpora in txt or CSV formats.
#
# In this file, rows contain documents and columns contain dimensions. Thus,
# document representations for a corpus of 100 documents generated from a model with 300 dimensions would yield an output file with 100 rows and 300 columns.

# %%
ddr.doc_vecs_from_txt(input_path="./explain_column.txt",
                      output_path ="./explain_output.tsv",
                      model = loaded_model,
                      num_features = loaded_num_features,
                      model_word_set = loaded_model_word_set)
# Out:
# Generating aggregate distributed representations of 803.0 texts.
# Percent: [----------] 0.0% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for u
# found u in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for g
# found g in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [#---------] 5.112219451371571% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for b
# found b in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for m
# found m in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [#---------] 10.224438902743142% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for g
# found g in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for u
# found u in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# Percent: [##--------] 15.336658354114713% looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for g
# found g in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for h
# found h in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [##--------] 20.448877805486283% looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [###-------] 25.561097256857856% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for b
# found b in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [###-------] 30.673316708229425% looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for l
# found l in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for u
# found u in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# Percent: [####------] 35.785536159601% looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# Percent: [####------] 40.89775561097257% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for g
# found g in model
# count is now 1.0
# looking for g
# found g in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [#####-----] 46.00997506234414% looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for c
# found c in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for a
# could not find a in model_word_set
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for b
# found b in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for l
# found l in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [#####-----] 51.12219451371571% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [######----] 56.234413965087285% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for q
# found q in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [######----] 61.34663341645885% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for c
# found c in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for j
# found j in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for d
# found d in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [#######---] 66.45885286783042% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [#######---] 71.571072319202% looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for b
# found b in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [########--] 76.68329177057358% looking for y
# found y in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for b
# found b in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for y
# found y in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for a
# could not find a in model_word_set
# looking for m
# found m in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# Percent: [########--] 81.79551122194513% looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for d
# found d in model
# count is now 1.0
# looking for c
# found c in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [#########-] 86.9077306733167% looking for u
# found u in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for f
# found f in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for p
# found p in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for s
# found s in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# Percent: [#########-] 92.01995012468828%
# /home/nick/anaconda3/envs/ddr/lib/python3.7/site-packages/ddr-0.1-py3.7.egg/ddr/get_vecs.py:42: RuntimeWarning: invalid value encountered in true_divide
#   avg_feature_vec = feature_vec / nwords
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for w
# found w in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for e
# found e in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# Percent: [##########] 97.13216957605985% looking for i
# found i in model
# count is now 1.0
# looking for f
# found f in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for t
# found t in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for m
# found m in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for o
# found o in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for c
# found c in model
# count is now 1.0
# looking for n
# found n in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
# looking for i
# found i in model
# count is now 1.0
#
# Finished calculating aggregate document representations
# Number of NA: 0

# %% [markdown]
# # Generate document-dictionary similarity measures
# Calculate the loading of each document on each dictionary
# dimension.
#
# This can be accomplished with the following function call:
# To generate document-dictionary similarity measures, the get_loadings() function
# can be used. This function takes five arguments:
# • agg_doc_vecs_path: the path to CSV file with aggregate document
# vectors as rows and a unique ID as the first column.
# • agg_dic_ves_path: the path to CSV file with aggregated dictionary
# vectors as columns.
# • out_path: path for output.
# • num_features: Dimensionality of the Word2Vec model used to generate
# vector representations.
# • delimiter: Delimiter to use in output CSV

# %%
ddr.get_loadings(agg_doc_vecs_path="./explain_output.tsv",
    agg_dic_vecs_path="./agg_dic_vecs_WTB.tsv",
    out_path="./document_dictionary_loadings_WTBcleaned.tsv",
    num_features=loaded_num_features)

# %% [markdown]
# #Warning: giving different ratings for "none." go back and check. WTF>

# %% [markdown]
# NOTE: THIS STEP TAKES THE LONGEST.
# Go back to original WTB_DDR_cleaned.CSV file.
#
# Find these missing values and if they are not obviously "wrong" in some way, cut and paste them into a new file.
# call file "WTB_DDR_cleaned2.csv"
# Remove the rows corresponding to these flagged IDs fro

# %% [markdown]
# Remove the rows corresponding to these flagged IDs from the original dataset.
# Rename original dataset WTB_DDR_cleaned2.csv
# create new column "ID_passed". This will give it an index which we can use to match it with the original ID from the original dataset.
# Copy/paste text column into txt file called "WTB_cleaned2.txt" and re-read. Manually fix anything and re-run it through analyses.

# %%
ddr.doc_vecs_from_txt(input_path="./PPL_WTB/WTB_DDR_cleaned2.txt",
                      output_path ="./PPL_WTB/output_WTBcleaned2.tsv",
                      model = loaded_model,
                      num_features = loaded_num_features,
                      model_word_set = loaded_model_word_set)
# Out:
# Generating aggregate distributed representations of 793.0 texts.
# Percent: [##########] 95.95959595959596%
# Finished calculating aggregate document representations
# Number of NA: 0

# %%
ddr.get_loadings(agg_doc_vecs_path="./PPL_WTB/output_WTBcleaned2.tsv",
    agg_dic_vecs_path="./PPL_WTB/agg_dic_vecs_WTB.tsv",
    out_path="./PPL_WTB/document_dictionary_loadings_WTBcleaned2.tsv",
    num_features=loaded_num_features)
# Out:
# reached here
# Percent: [#####-----] 49.401386263390044% Failed to calculate 6 loadings due to missing values.
# IDs for documents with missing values:
#
#  ['276', '378', '401', '413', '616', '644']
